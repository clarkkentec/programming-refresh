# %%
print("Hi! I'm testing this VSCode x Git")
print("Testing whether I can create a file, commit and push from VSCode")
# Out:
# Hi! I'm testing this VSCode x Git
# Testing whether I can create a file, commit and push from VSCode

# %%
print("What is commit?")
print("What is push?")
print("I've learnt that commit is like saving a checkpoint of your code, and push is like uploading that checkpoint to a remote repository like GitHub.")

# %% [markdown]
# What I've learnt so far:
# 1) VSCode, Homebrew and Git Install
# 2) Creating a repository in Git (Browser) and how to reflect it in VSCode
#     a) Creating the repository in the browser is the first stage.
#     b) To get it in VSCode - Go to terminal and 'git clone' the https link to the repository
#
# 3) How to create a Jupyter Notebook file and then 'commit' changes and 'staging' commits
#     a)
#
#
#
# 4) ***still need to learn*** what does 'Push' 'Pull' 'Branch' mean?
#
# Where does everything save then?
# What is the point of the file on my iCloud if it's already in Git?
# Is there a better way to do 3? (I.e creating a jupyter notebook file)
# Do I really know the upload process?
